# %%
import pandas as pd
from myhelpers import config_plots
config_plots.global_settings()
import os

# %%
experimentsPath="/raid/elhamod/Fish/experiments/"
experimentName="biology_paper_curated4_Medium_lowalpha"
trial_hash="fe92041f4795ea893a098591d337fdfaaecfbdac66e32df0394f6213"

# %%
file_path = os.path.join(experimentsPath,experimentName ,'models', trial_hash, 'adaptive_smoothing.csv')

df = pd.read_csv(file_path)
df = df.copy().replace(r"_", "", regex=True)
df.columns = df.columns.str.replace('_','')

df[['lambdafine','lambdacoarse']].plot()
df[['lossfine','losscoarse']].plot()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Imports

# %%
from configParser import ConfigParser, getModelName

# %% [markdown]
# Parameters

# %%
experimentName = "Butterflies_round1_0"


# When adding a new parameter:
# 1- Add it here
# 2- Add it to configParser where necessary
# 3- Run fix parameters jupyter notebook if necessary

# Do not change the order!
params = {
    # Do not change for multi/hyperp experiments
    "image_path": "LowResolution", # "cifar-100-python", "Curated4/Easy_50"
    "suffix":'preprocessed', 
    "useCrossValidation": False,
    
    # dataset
    "img_res": 224, #224 #32, 448
    "augmented": True,

    # training
    "batchSize": 128, #128, # Bigger is more stable (256)
    "learning_rate": 0.001,  # 0.1,#0.001,#0.001, is best #0.0001,#0.1, #0.01, #0.0003, # 0.00005
    "numOfTrials":3, #5
    "fc_layers": 1,
    "pretrained": True,
    "epochs": 120, #120
    "patience": -1,#12,#-1, # None = "epochs"
    "optimizer": "adabelief", # "SGD",#"adabelief",#"Adam",
    "scheduler": "plateau",
    "weightdecay": 0.01, #0.0001, #0.01, #0.0001
    "scheduler_gamma":0.5,
    "scheduler_patience":15,   
    
#     Cifar	lr1e-3	weightdecay5e-4
# ImageNet	lr1e-3	weightdecay1e-2
    
    "modelType":"BB", #BB DISCO DSN HGNN  "exRandomFeatures" "PhyloNN" ####HGNN_cat "HGNN_add" 
    
    "lambda": 1,#0.01, 
    "two_phase_lambda": False,

    "tl_model": "ResNet18", # Keep 'ResNet18', 'ResNet50', 'CIFAR', 'NIN'
    "link_layer": "avgpool", # layer name should be consistent with tl_model layer names. avgpool,"layer3"
    
    "adaptive_smoothing": False,
    "adaptive_lambda": 0.1,#0.015, #optimized for time
    "adaptive_alpha": 0.5,#0.8, #optimized for time
    
    "tripletEnabled": True,
    "regularTripletLoss": False,
    "tripletSamples": 8,
    "tripletSelector": "semihard",
    "tripletMargin": 2, #0.2
    "triplet_layers_dic": "layer2,layer4",
    
    "L1reg": False,

    "phylogeny_loss": False, 
    
    "grayscale": False, #Keep False
    "tl_extralayer": False, #Keep False
    "random_fitting": False, #Keep False
    
    "phyloDistances": "0.75,0.5,0.25",
    "addKernelOrthogonality":False,
}

experimentsPath= "/raid/elhamod/Butterflies2/experiments/" # "/raid/elhamod/CIFAR_HGNN/experiments/"
dataPath="/raid/elhamod/Butterflies2/Datasets" #"/raid/elhamod/Fish" "/raid/elhamod/"

# %% [markdown]
# Create file

# %%
cp = ConfigParser(experimentsPath, dataPath, experimentName)

selected_hyperp_params = [
#     {'adaptive_smoothing': True, },
#     {'adaptive_smoothing': False, 'lambda': 0.01},
#     {'adaptive_smoothing': False, 'lambda': 0},
#     {"training_count":0.32,"validation_count":0.08,},
#     {"training_count":0.32,"validation_count":0.08,'downsample': True, 'takeFromIntermediate': False, 'takeFromIntermediateOutput':-1 },
#     {"training_count":0.16,"validation_count":0.04,'downsample': True, 'takeFromIntermediate': False, 'takeFromIntermediateOutput':-1 },
#     {"training_count":0.16,"validation_count":0.04}
    
#     {"training_count":0.64,"validation_count":0.16,'downsample': True, 'takeFromIntermediate': False, 'takeFromIntermediateOutput':-1 },
#     {"training_count":0.64,"validation_count":0.16}
    
#     {"augmented": True, "aug_profile": "withRotation_PCA1.5", "suffix": 'biology_paper_200max' }, 
#     {"augmented": False, "aug_profile": None }, 
#     {"augmented": True, "aug_profile": "withRotation_PCA1.5" },
    
#      {"modelType": 'DISCO'}, ## BB
#      {"modelType": 'HGNN_add', "numOfTrials":1, "adaptive_alpha": 0.1, "adaptive_lambda": 0.1},
#      { "modelType": 'HGNN_add', "fc_layers": 1},
#      { "modelType": 'BB', "fc_layers": 1},
#      { "modelType": 'BB', "fc_layers": 2}
#     {'batchSize':16, 'learning_rate': 0.0001},
#     {'batchSize':16, 'learning_rate': 0.00005},
#     {'batchSize':16, 'learning_rate': 0.00001},
#     {'batchSize':16, 'learning_rate': 0.000005},
#     {'batchSize':8, 'learning_rate': 0.0001},
#     {'batchSize':8, 'learning_rate': 0.00005},
#     {'batchSize':8, 'learning_rate': 0.00001},
#     {'batchSize':8, 'learning_rate': 0.000005},
#     {'batchSize':32, 'learning_rate': 0.0001},
#     {'batchSize':32, 'learning_rate': 0.00005},
#     {'batchSize':32, 'learning_rate': 0.00001},
#     {'batchSize':32, 'learning_rate': 0.000005}
#     {'batchSize':64, 'learning_rate': 0.0001},
#     {'batchSize':128, 'learning_rate': 0.0001},
#     {'batchSize':64, 'learning_rate': 0.00005},
#     {'batchSize':128, 'learning_rate': 0.00005},
#     {'batchSize':8, 'learning_rate': 0.0001},
#     {'batchSize':16, 'learning_rate': 0.0001},
#     {'batchSize':8, 'learning_rate': 0.00005},
#     {'batchSize':16, 'learning_rate': 0.00005},
#     {'batchSize':32, 'learning_rate': 0.0001},
#     {'batchSize':32, 'learning_rate': 0.00005},
#     {"modelType": 'HGNN_add', "numOfTrials":1, "adaptive_alpha": 0.1, "adaptive_lambda": 0.01},
#     {"displayName": 'Fish replicate paper params HGNN', "modelType": "HGNN", "adaptive_alpha": 0.9},
#     {"displayName": 'Fish replicate paper params HGNN low alpha', "modelType": "HGNN"},
#     {"displayName": 'Fish replicate paper params DISCO', "modelType": "DISCO"},
#     {"displayName": 'Fish replicate paper params Adabelief', "optimizer": "adabelief",'learning_rate': 0.001, "weightdecay": 0.01},
#     {"displayName": 'Fish replicate paper params Triplet alpha0.9', "tripletEnabled": True, "adaptive_alpha": 0.9},
#     {"displayName": 'Fish replicate paper params Triplet Adabelief', "tripletEnabled": True, "optimizer": "adabelief",'learning_rate': 0.001, "weightdecay": 0.01},
#     {"displayName": 'Fish replicate paper params Triplet alpha0.5', "tripletEnabled": True, "adaptive_alpha": 0.5},
#     {"displayName": 'Fish replicate paper params step', "tripletEnabled": True, "scheduler": "step"},
#     {"displayName": 'Fish replicate paper params cosine', "tripletEnabled": True, "scheduler": "cosine"},
#     {"adaptive_lambda":0.1, 'tripletMargin': 3, 'displayName': 'adaptive lambda big margin 3 alpha 0.5'},
#     {"adaptive_lambda":1,'tripletMargin': 3, 'displayName':'adaptive lambda bigger margin 3 alpha 0.5'},
#     {"adaptive_lambda":0.1, 'displayName':'adaptive lambda big margin 0.2 alpha 0.5'},
#     {"adaptive_lambda":0.1, 'displayName':'adaptive lambda bigger margin 0.2 alpha 0.5'},
#     {'displayName': 'Fish4-BB-SGD', "learning_rate": 0.1},
#     {'displayName': 'Fish4-BB-SGD-lr0.01', "learning_rate": 0.01},
#     {'displayName': 'Fish4-BB-Adabelief-gamma0.1'},
#     {'displayName': 'Fish4-triplet-cosine',"tripletEnabled": True,"scheduler": "cosine"},
#     {'displayName': 'Fish4-triplet-cosine-alpha0.5-margin2',"tripletMargin": 2,"tripletEnabled": True,"adaptive_alpha": 0.5,"learning_rate": 0.0005,"scheduler": "cosine"},
#     {'displayName': 'Fish4-triplet-alpha0.9-margin1', "tripletEnabled": True,"adaptive_alpha": 0.9,"tripletMargin": 1},
#     {'displayName': 'Fish4-triplet-alpha0.9-margin3', "tripletEnabled": True,"adaptive_alpha": 0.9,"tripletMargin": 3},
#     {'displayName': 'Fish4-triplet-alpha0.9', "tripletEnabled": True,"adaptive_alpha": 0.9},
#     {'displayName': 'Fish4-triplet-alpha0.1', "tripletEnabled": True},
#     {'displayName': 'Fish4-triplet-cosine*3-smallerlr-alpha0.5-margin2',"tripletMargin": 2,"tripletEnabled": True,"adaptive_alpha": 0.5, "learning_rate": 0.0005, "scheduler": "cosine", 'cosine_patience':4},
#     {'displayName': 'Fish4-triplet-cosine-largerbatchsize-smallerlr-alpha0.5-margin2',"tripletMargin": 2,"adaptive_alpha": 0.5, "learning_rate": 0.0005,"tripletEnabled": True, "scheduler": "cosine", 'scheduler_patience':12},
#     {'displayName': 'Fish alpha 0.1', "adaptive_alpha": 0.1},
#     {'displayName': 'Fish alpha 0.5', "adaptive_alpha": 0.5},
#     {'displayName': 'Fish alpha 0.8', "adaptive_alpha": 0.8},
#     {'displayName': 'Fish lr 0.1', "learning_rate": 0.1},
#     {'displayName': 'Fish lr 0.01', "learning_rate": 0.01},
#     {'displayName': 'Fish lr 0.05', "learning_rate": 0.005},
#     {'displayName': 'Fish no triplet', "tripletEnabled": False},
#     {'displayName': 'Fish from scratch no triplet', "tripletEnabled": False},
#     {'displayName': 'Fish from scratch triplet'},
#     {'displayName': 'Fish preresnet from scratch no triplet', "tl_model": 'preResNet', "tripletEnabled": False},
#     {'displayName': 'Fish preresnet from scratch triplet', "tl_model": 'preResNet'},
#     {'displayName': 'Fish resnet56 from scratch no triplet', "tl_model": 'ResNet56', "tripletEnabled": False},
#     {'displayName': 'Fish resnet56 from scratch triplet', "img_res": 112, "tl_model": 'ResNet56'},
#     {"adaptive_smoothing": True,'displayName': 'SGD with triplet'},
#      {"tripletMargin":0.2, 'displayName': 'small margin 0.2'},
#     {"tripletMargin":6, 'displayName': 'large margin 6'},
#     {"tripletMargin":20, 'displayName': 'very large margin 20'},
#     {"tripletSelector":'hard', 'displayName': 'hard'},
#     {'tripletSelector': 'random', 'displayName': 'random'},
    
#      {"modelType": 'DSN'},
#     {"phylogeny_loss": False},
#     {'displayName': 'Fish-CE-newtree',"epochs": 160},
#     {'displayName': 'Fish-MSE-newtree',"phylogeny_loss": "MSE","epochs": 160},
#     {'displayName': 'Fish-KLDiv-newtree',"phylogeny_loss": "KLDiv","epochs": 160},
#      {"adaptive_lambda": 0.1, "numOfTrials":3,"adaptive_alpha":0.7},
#      {"adaptive_lambda": 0.1, "numOfTrials":3,"adaptive_alpha":0.5},
#      {"adaptive_lambda": 0.1, "numOfTrials":3,"adaptive_alpha":0.1},
#      {"adaptive_lambda": 0.1, "numOfTrials":3,"adaptive_alpha":0.9},
#     {"adaptive_smoothing": False, "lambda": 0.1}, ## HGNN constant lambda
#     {"adaptive_smoothing": False, "lambda": 0.01}, ## HGNN constant lambda smaller
#     {"adaptive_alpha": 0.7, "adaptive_lambda": 0.01}, #HGNN adaptive smoothing
#     {"adaptive_alpha": 0.9, "adaptive_lambda": 0.01}, #HGNN more smooth higher alpha
   
    



#     {'displayName': 'Fish-s-triplet-hier-alpha0.1', "tripletEnabled": True, "adaptive_alpha": 0.1},
#     {'displayName': 'Fish-s-triplet-hier-alpha0.9', "tripletEnabled": True, "adaptive_alpha": 0.9},
#     {'displayName': 'Fish-s-triplet-hier-gamma0.5', "tripletEnabled": True,"scheduler_gamma":0.5},
#     {'displayName': 'Fish-s-triplet-hier-cos80', "tripletEnabled": True, "scheduler_patience":80, "scheduler": "cosine"},
#     {'displayName': 'Fish-s-triplet-hier-cos80-gamma0.5', "tripletEnabled": True, "scheduler_patience":80, "scheduler": "cosine","scheduler_gamma":0.5},
#     {'displayName': 'Fish-s-triplet-hier-cos40', "tripletEnabled": True, "scheduler_patience":40, "scheduler": "cosine"},
#     {'displayName': 'Fish-s-triplet-hier-cos40-gamma0.5', "tripletEnabled": True, "scheduler_patience":40, "scheduler": "cosine","scheduler_gamma":0.5},
#     {'displayName': 'Fish-s-triplet-hier-cos10', "tripletEnabled": True, "scheduler_patience":10, "scheduler": "cosine"},
#     {'displayName': 'Fish-s-triplet-hier-cos10-gamma0.5', "tripletEnabled": True, "scheduler_patience":10, "scheduler": "cosine","scheduler_gamma":0.5},
#     {'displayName': 'Fish-s-triplet-hier-step10', "tripletEnabled": True, "scheduler_patience":10, "scheduler": "step"},
#     {'displayName': 'Fish-s-triplet-hier-step10-gamma0.5', "tripletEnabled": True, "scheduler_patience":10, "scheduler": "step","scheduler_gamma":0.5},
#     {'displayName': 'Fish-s-triplet-hier-step15', "tripletEnabled": True, "scheduler_patience":15, "scheduler": "step"},
#     {'displayName': 'Fish-s-triplet-hier-step15-gamma0.5', "tripletEnabled": True, "scheduler_patience":15, "scheduler": "step","scheduler_gamma":0.5},

#     {'displayName': 'Fish-s3-BBlonger2', "epochs": 120, "learning_rate": 0.0001},
#     {'displayName': 'Fish-s3-hier_margin10-staticlambda', "tripletEnabled": True, "tripletMargin": 10,"adaptive_smoothing": False, "lambda": 0.2},
#     {'displayName': 'Fish-s3-hierMSE-staticlambda', "tripletEnabled": True,"phylogeny_loss": "MSE","adaptive_smoothing": False, "lambda": 0.2},
#     {'displayName': 'Fish-s3-hierKLDiv-staticlambda', "tripletEnabled": True,"phylogeny_loss": "KLDiv","adaptive_smoothing": False, "lambda": 0.2},
#     {'displayName': 'Fish-s2-DISCO',"modelType":"DISCO" },
#     {'displayName': 'Fish-s2-DISCO0.1',"modelType":"DISCO","adaptive_alpha": 0.1},
#     {'displayName': 'Fish-s2-DISCO0.9',"modelType":"DISCO","adaptive_alpha": 0.9},
#     {'displayName': 'Fish-s2-HGNN',"modelType":"HGNN" },
#     {'displayName': 'Fish-s2-HGNN0.1',"modelType":"HGNN","adaptive_alpha": 0.1},
#     {'displayName': 'Fish-s2-HGNN0.9',"modelType":"HGNN","adaptive_alpha": 0.9},
    
#     {'displayName': 'Fish-triplet-hier-layer3layer4', "tripletEnabled": True, "triplet_layers_dic": "layer3,layer4"},
#     {'displayName': 'Fish-triplet-hier-notpretrained', "pretrained": False, "tripletEnabled": True},
#     {'displayName': 'Fish-BB-notpretrained',"pretrained": False},
#     {'displayName': 'Fish-triplet-normal-notpretrained', "pretrained": False, "tripletEnabled": True, "regularTripletLoss": True},
  
#     {'displayName': 'Fish-triplet-hier-twophase-lambda0.01', "tripletEnabled": True, "two_phase_lambda": True, "adaptive_smoothing": False, "lambda": 0.01,},
#     {'displayName': 'Fish-triplet-hier-twophase-lambda0.1', "tripletEnabled": True, "two_phase_lambda": True, "adaptive_smoothing": False, "lambda": 0.1,},
#     {'displayName': 'Fish-triplet-hier-twophase-lambda0.2', "tripletEnabled": True, "two_phase_lambda": True, "adaptive_smoothing": False, "lambda": 0.2,},
#     {'displayName': 'Fish-triplet-hier-twophase-lambda0.5', "tripletEnabled": True, "two_phase_lambda": True, "adaptive_smoothing": False, "lambda": 0.5,},
    
#     {'displayName': 'Fish30-L1-MSE', "phylogeny_loss": "MSE", "L1reg": True, "adaptive_smoothing": False, "lambda": 0.01},
#     {'displayName': 'Fish30-L1-KLDiv', "phylogeny_loss": "KLDiv", "L1reg": True, "adaptive_smoothing": False, "lambda": 0.01},
#     {'displayName': 'Fish30-L1-CE', "adaptive_smoothing": False, "L1reg": True, "lambda": 0.01},
#     {'displayName': 'Fish30-MSE', "phylogeny_loss": "MSE", "L1reg": False, "adaptive_smoothing": False, "lambda": 0.01},
#     {'displayName': 'Fish30-KLDiv', "phylogeny_loss": "KLDiv", "L1reg": False, "adaptive_smoothing": False, "lambda": 0.01},
#     {'displayName': 'Fish30-CE', "adaptive_smoothing": False, "L1reg": False, "lambda": 0.01},
    
#     {'displayName': 'Fish-224scratch-BB', "img_res": 224, "pretrained": False},
#     {'displayName': 'Fish-224scratch-triplet', "img_res": 224, "pretrained": False, "tripletEnabled": True},
#     {'displayName': 'Fish-224scratch-triplet-normal', "img_res": 224, "pretrained": False, "tripletEnabled": True, "regularTripletLoss": False}

    
#     {'displayName': 'Fish50-5run-BB-finetuning-adaptive', "adaptive_smoothing": True},
#     {'displayName': 'Fish50-5run-BB-finetuning-lambda0.1', "lambda": 0.1},
#     {'displayName': 'Fish50-5run-BB-finetuning-adaptive-alpha0.1-lambd15', "adaptive_smoothing": True, "adaptive_alpha": 0.1,"adaptive_lambda": 15},
#     {'displayName': 'Fish50-5run-BB-finetuning-base'},
#     {'displayName': 'Fish50-5run-BB-finetuning-lambda0.01', "lambda": 0.01},
#     {'displayName': 'Fish50-5run-BB-finetuning-adaptive-alpha0.3-lambd15', "adaptive_smoothing": True, "adaptive_alpha": 0.3,"adaptive_lambda": 15},
    
   
#     {'displayName': 'Fish50-5run-HGNN-crossval-5fold-2'},
#     {'displayName': 'Fish30-5runs-MSE',"phylogeny_loss": "MSE"},
#     {'displayName': 'Fish30-5runs-hiertriplet',"tripletEnabled": True, "batchSize": 100},
#     {'displayName': 'Fish30-5runs-hiertripletAndMSE',"tripletEnabled": True,"phylogeny_loss": "MSE" , "batchSize": 100},
#     {'displayName': 'Fish30-5runs-normaltriplet',"tripletEnabled": True, "regularTripletLoss": True, "batchSize": 100},
#     {'displayName': 'Fish30-hier-constantlambda0.1', "tripletEnabled": True, "adaptive_smoothing": False, "lambda": 0.1},
#     {'displayName': 'Fish30-hier-constantlambda0.2', "tripletEnabled": True, "adaptive_smoothing": False, "lambda": 0.2},
#     {'displayName': 'Fish30-hier-layer3', "tripletEnabled": True, "triplet_layers_dic": "layer3,layer4",},
    
    
    
    # To be used later
#     {'displayName': 'Fish-milestone-triplet-hier', "tripletEnabled": True},
#     {'displayName': 'Fish30-5run-PhyloNN-adaptivelambda-intraKorthogonality', "addKernelOrthogonality":True, "adaptive_smoothing": True},
#     {'displayName': 'Fish30-5run-PhyloNN-lambda1'},
#     {'displayName': 'Fish30-5run-PhyloNN-lambda0.1', "lambda": 0.1},
#     {'displayName': 'Fish30-5run-PhyloNN-adaptivelambda-alpha0.05-intraKorthogonality2', "addKernelOrthogonality":True, "adaptive_smoothing": True,"adaptive_lambda": 0.1, "adaptive_alpha": 0.05},
#     {'displayName': 'Fish30-5run-PhyloNN-smalldistances-intraKorthogonality', "addKernelOrthogonality":True, "phyloDistances": "0.5,0.3,0.1"},
#     {'displayName': 'Fish30-5run-PhyloNN-largedistances', "phyloDistances": "0.9,0.7,0.5"},
    
    {'displayName': 'default'},
    {'displayName': 'no_triplet_loss', "tripletEnabled": False},
    {'displayName': 'reg_triplet_loss', "regularTripletLoss": True},
    {'displayName': 'lambda0.1', "lambda": 0.1},
    {'displayName': 'lambda0.01', "lambda": 0.01},
    {'displayName': 'tripletMargin0.2', "tripletMargin": 0.2},
    
#     {'displayName': 'batch_64', "batchSize": 64},
#     {'displayName': 'batch_264', "batchSize": 264},
#     {'displayName': 'lr0.1', "learning_rate": 0.1},
#     {'displayName': 'lr0.01', "learning_rate": 0.01},
#     {'displayName': 'lr0.0001', "learning_rate": 0.0001},


#     {'displayName': 'Fish30-5run-SGD10-BB1momentumweightdecay10-4', "modelType":"BB"},
#     {'displayName': 'Fish-crossval-HGNN-Fish50',"modelType":"HGNN"},
#     {'displayName': 'Fish-crossval-BB-SGDfaster-Fish30',  "learning_rate": 0.1,  "optimizer": "SGD", "image_path": "Curated4/Easy_30"},
#     {'displayName': 'Fish-crossval-HGNN-Fish30',"modelType":"HGNN", "image_path": "Curated4/Easy_50"},
#     {'displayName': 'Fish-milestone-triplet-normal', "tripletEnabled": True, "regularTripletLoss": True},
#     {'displayName': 'Fish-milestone-DISCO',"modelType":"DISCO"},

]

cp.write(params, selected_hyperp_params, "Select")
# Out:
# '/raid/elhamod/Butterflies2/experiments/Butterflies_round1_0/params.json'

# %%
for i in cp.getExperiments():
    print(i)
    print(getModelName(i))
# Out:
# {'image_path': 'LowResolution', 'suffix': 'preprocessed', 'useCrossValidation': False, 'img_res': 224, 'augmented': True, 'batchSize': 128, 'learning_rate': 0.001, 'numOfTrials': 3, 'fc_layers': 1, 'pretrained': True, 'epochs': 120, 'patience': -1, 'optimizer': 'adabelief', 'scheduler': 'plateau', 'weightdecay': 0.01, 'scheduler_gamma': 0.5, 'scheduler_patience': 15, 'modelType': 'BB', 'lambda': 1, 'two_phase_lambda': False, 'tl_model': 'ResNet18', 'link_layer': 'avgpool', 'adaptive_smoothing': False, 'adaptive_lambda': 0.1, 'adaptive_alpha': 0.5, 'tripletEnabled': True, 'regularTripletLoss': False, 'tripletSamples': 8, 'tripletSelector': 'semihard', 'tripletMargin': 2, 'triplet_layers_dic': 'layer2,layer4', 'L1reg': False, 'phylogeny_loss': False, 'grayscale': False, 'tl_extralayer': False, 'random_fitting': False, 'phyloDistances': '0.75,0.5,0.25', 'addKernelOrthogonality': False, 'displayName': 'default', 'noSpeciesBackprop': False, 'phylogeny_loss_epsilon': 0.03}
# ...

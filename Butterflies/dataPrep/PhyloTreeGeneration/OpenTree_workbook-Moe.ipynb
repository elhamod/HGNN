# %% [markdown]
# Install required packages

# %%
# Provides tools for checking phylogeny tree against online ground truth
# !pip install opentree

# provides tools for monophyly and phylogeny
# !pip install biopython
from Bio import Phylo

# provides tools for monophyly and phylogeny
! pip install ete3
from ete3 import Tree

# used to render the tree beautifully
# !pip install pyqt5
# set flag for rendering
import os
os.environ['QT_QPA_PLATFORM']='offscreen'
# Out:
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Requirement already satisfied: opentree in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (0.0.3)
# Requirement already satisfied: requests>=2.18 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from opentree) (2.23.0)
# Requirement already satisfied: setuptools in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from opentree) (56.2.0)
# Requirement already satisfied: DendroPy>=4.4.0 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from opentree) (4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from requests>=2.18->opentree) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from requests>=2.18->opentree) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from requests>=2.18->opentree) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from requests>=2.18->opentree) (2019.11.28)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/elhamod/melhamodenv3/bin/python3 -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Requirement already satisfied: biopython in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (1.78)
# Requirement already satisfied: numpy in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from biopython) (1.18.4)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/elhamod/melhamodenv3/bin/python3 -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Requirement already satisfied: ete3 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (3.1.2)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/elhamod/melhamodenv3/bin/python3 -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://packagecloud.io/github/git-lfs/pypi/simple
# Requirement already satisfied: pyqt5 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /home/elhamod/melhamodenv3/lib/python3.6/site-packages (from pyqt5) (12.8.1)
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/home/elhamod/melhamodenv3/bin/python3 -m pip install --upgrade pip' command.

# %%
# from io import StringIO

# # Tree
# handleD = StringIO("((E:0.2,D:0.1,C:0.1,B:0.3)2:0.3,A:0.5)1;")
# treeD = Phylo.read(handleD,"newick")

# # Distance
# treeD.distance("E","D")

# %% [markdown]
# By default, a tree does not have distances defined. We add those distances. Each edge distance=1

# %%
#read tree. This tree was provided by Wasila
treefile = "/raid/elhamod/Fish/Taxa/bgnn-tree-2021-01-29.tre"
tree = Phylo.read(treefile, "newick")

# adding branch lengths
clades = tree.find_clades()
for clade in clades:
    clade.branch_length = 1
    
# example of a distance
print(tree)
# Out:
# Tree(rooted=False, weight=1.0)
#     Clade(branch_length=1, name='Neopterygii_ott471203')
#         Clade(branch_length=1, name='Clupeocephala_ott285819')
#             Clade(branch_length=1, name='Otomorpha_ott761450')
#                 Clade(branch_length=1, name='Otophysi_ott285818')
#                     Clade(branch_length=1, name='mrcaott231ott2200')
#                         Clade(branch_length=1, name='mrcaott231ott3121')
#                             Clade(branch_length=1, name='mrcaott231ott103051')
#                                 Clade(branch_length=1, name='Notropis_greenei_ott103051')
#                                 Clade(branch_length=1, name='Notropis_nazas_ott338646')
#                                 Clade(branch_length=1, name='Notropis_cummingsae_ott608193')
#                                 Clade(branch_length=1, name='mrcaott231ott101080')
#                                     Clade(branch_length=1, name='Notropis_hudsonius_ott135051')
#                                     Clade(branch_length=1, name='Hybopsis_dorsalis_ott419160')
#                                     Clade(branch_length=1, name='mrcaott231ott53720')
#                                         Clade(branch_length=1, name='mrcaott231ott50039')
#                                             Clade(branch_length=1, name='mrcaott231ott96047')
#                                                 Clade(branch_length=1, name='mrcaott152460ott260114')
#                                                     Clade(branch_length=1, name='Lythrurus_umbratilis_ott260114')
#                                                     Clade(branch_length=1, name='Lythrurus_ardens_ott834748')
#                                                 Clade(branch_length=1, name='mrcaott96047ott421896')
#                                                     Clade(branch_length=1, name='mrcaott96047ott538614')
#                                                         Clade(branch_length=1, name='mrcaott96047ott96051')
#                                                             Clade(branch_length=1, name='Luxilus_chrysocephalus_ott96048')
#                                                             Clade(branch_length=1, name='Luxilus_cornutus_ott96051')
#                                                         Clade(branch_length=1, name='Luxilus_zonatus_ott538618')
#                                                     Clade(branch_length=1, name='Notropis_heterolepis_ott832483')
#                                             Clade(branch_length=1, name='mrcaott50039ott53715')
#                                                 Clade(branch_length=1, name='mrcaott50039ott50045')
#                                                     Clade(branch_length=1, name='mrcaott171812ott351750')
#                                                         Clade(branch_length=1, name='Cyprinella_lutrensis_ott351753')
#                                                         Clade(branch_length=1, name='mrcaott351750ott373838')
#                                                             Clade(branch_length=1, name='Cyprinella_venusta_ott351750')
#                                                             Clade(branch_length=1, name='mrcaott373838ott597397')
#                                                                 Clade(branch_length=1, name='Cyprinella_spiloptera_ott373838')
#                                                                 Clade(branch_length=1, name='Cyprinella_whipplei_ott597397')
#                                                     Clade(branch_length=1, name='mrcaott570799ott570805')
#                                                         Clade(branch_length=1, name='Cyprinella_camura_ott570799')
#                                                         Clade(branch_length=1, name='Cyprinella_galactura_ott570805')
#                                                 Clade(branch_length=1, name='mrcaott53715ott222462')
#                                                     Clade(branch_length=1, name='mrcaott53715ott103057')
#                                                         Clade(branch_length=1, name='mrcaott53715ott53730')
#                                                             Clade(branch_length=1, name='mrcaott53715ott419165')
#                                                                 Clade(branch_length=1, name='mrcaott53715ott53725')
#                                                                     Clade(branch_length=1, name='Notropis_rubricroceus_ott53715')
#                                                                     Clade(branch_length=1, name='Notropis_lutipinnis_ott703205')
#                                                                 Clade(branch_length=1, name='mrcaott419165ott443771')
#                                                                     Clade(branch_length=1, name='Notropis_edwardraneyi_ott443771')
#                                                                     Clade(branch_length=1, name='Notropis_blennius_ott419165')
#                                                             Clade(branch_length=1, name='mrcaott103071ott550208')
#                                                                 Clade(branch_length=1, name='Notropis_chalybaeus_ott103071')
#                                                                 Clade(branch_length=1, name='mrcaott550208ott914937')
#                                                                     Clade(branch_length=1, name='Notropis_texanus_ott550208')
#                                                                     Clade(branch_length=1, name='Notropis_xaenocephalus_ott914937')
#                                                         Clade(branch_length=1, name='Ericymba_buccata_ott269524')
#                                                         Clade(branch_length=1, name='mrcaott258125ott258132')
#                                                             Clade(branch_length=1, name='mrcaott258125ott280272')
#                                                                 Clade(branch_length=1, name='Notropis_anogenus_ott258125')
#                                                                 Clade(branch_length=1, name='mrcaott280272ott550199')
#                                                                     Clade(branch_length=1, name='Notropis_longirostris_ott280272')
#                                                                     Clade(branch_length=1, name='Notropis_nubilus_ott550199')
#                                                             Clade(branch_length=1, name='mrcaott258132ott443777')
#                                                                 Clade(branch_length=1, name='Notropis_heterodon_ott258132')
#                                                                 Clade(branch_length=1, name='mrcaott443777ott522918')
#                                                                     Clade(branch_length=1, name='Notropis_boops_ott443777')
#                                                                     Clade(branch_length=1, name='Notropis_chihuahua_ott522918')
#                                                     Clade(branch_length=1, name='mrcaott351732ott351738')
#                                                         Clade(branch_length=1, name='Notropis_procne_ott351732')
#                                                         Clade(branch_length=1, name='mrcaott351738ott351741')
#                                                             Clade(branch_length=1, name='Notropis_topeka_ott351738')
#                                                             Clade(branch_length=1, name='Notropis_stramineus_ott351741')
#                                         Clade(branch_length=1, name='mrcaott53720ott550187')
#                                             Clade(branch_length=1, name='mrcaott53720ott403724')
#                                                 Clade(branch_length=1, name='mrcaott53720ott338652')
#                                                     Clade(branch_length=1, name='Notropis_leuciodus_ott338652')
#                                                     Clade(branch_length=1, name='mrcaott53720ott351735')
#                                                         Clade(branch_length=1, name='Notropis_volucellus_ott351735')
#                                                         Clade(branch_length=1, name='mrcaott53720ott443786')
#                                                             Clade(branch_length=1, name='mrcaott53720ott555686')
#                                                                 Clade(branch_length=1, name='Notropis_spectrunculus_ott53720')
#                                                                 Clade(branch_length=1, name='Notropis_buchanani_ott555686')
#                                                             Clade(branch_length=1, name='Notropis_wickliffi_ott563834')
#                                                 Clade(branch_length=1, name='mrcaott403724ott443780')
#                                                     Clade(branch_length=1, name='Notropis_ariommus_ott443780')
#                                                     Clade(branch_length=1, name='mrcaott403724ott443765')
#                                                         Clade(branch_length=1, name='mrcaott403724ott443768')
#                                                             Clade(branch_length=1, name='mrcaott403724ott403731')
#                                                                 Clade(branch_length=1, name='Notropis_micropteryx_ott403724')
#                                                                 Clade(branch_length=1, name='mrcaott403731ott565581')
#                                                                     Clade(branch_length=1, name='Notropis_percobromus_ott403731')
#                                                                     Clade(branch_length=1, name='Notropis_rubellus_ott565581')
#                                                             Clade(branch_length=1, name='Notropis_stilbius_ott550184')
#                                                         Clade(branch_length=1, name='Notropis_atherinoides_ott636312')
#                                             Clade(branch_length=1, name='mrcaott550190ott550202')
#                                                 Clade(branch_length=1, name='Notropis_telescopus_ott550190')
#                                                 Clade(branch_length=1, name='Notropis_photogenis_ott550202')
#                                         Clade(branch_length=1, name='mrcaott439044ott538612')
#                                             Clade(branch_length=1, name='Notropis_bifrenatus_ott439044')
#                                             Clade(branch_length=1, name='Luxilus_coccogenis_ott538612')
#                                     Clade(branch_length=1, name='mrcaott101080ott260128')
#                                         Clade(branch_length=1, name='Hybopsis_amblops_ott269514')
#                                         Clade(branch_length=1, name='Opsopoeodus_emiliae_ott260128')
#                                 Clade(branch_length=1, name='Phenacobius_uranops_ott610364')
#                             Clade(branch_length=1, name='Chrosomus_ott149611')
#                                 Clade(branch_length=1, name='Chrosomus_neogaeus_ott319954')
#                                 Clade(branch_length=1, name='mrcaott63845ott319949')
#                                     Clade(branch_length=1, name='Chrosomus_eos_ott63845')
#                                     Clade(branch_length=1, name='Chrosomus_erythrogaster_ott319949')
#                         Clade(branch_length=1, name='mrcaott169910ott185860')
#                             Clade(branch_length=1, name='Cyprinus_carpio_ott429083')
#                             Clade(branch_length=1, name='Carassius_auratus_ott1005907')
#                     Clade(branch_length=1, name='Noturus_ott357170')
#                         Clade(branch_length=1, name='Noturus_exilis_ott678206')
#                         Clade(branch_length=1, name='mrcaott101864ott130869')
#                             Clade(branch_length=1, name='mrcaott101864ott621604')
#                                 Clade(branch_length=1, name='Noturus_insignis_ott621604')
#                                 Clade(branch_length=1, name='Noturus_leptacanthus_ott621583')
#                             Clade(branch_length=1, name='mrcaott282525ott411931')
#                                 Clade(branch_length=1, name='mrcaott282525ott676110')
#                                     Clade(branch_length=1, name='Noturus_eleutherus_ott411926')
#                                     Clade(branch_length=1, name='Noturus_albater_ott676110')
#                                 Clade(branch_length=1, name='Noturus_hildebrandi_ott652781')
#                 Clade(branch_length=1, name='mrcaott482298ott491656')
#                     Clade(branch_length=1, name='Alosa_chrysochloris_ott482298')
#                     Clade(branch_length=1, name='Alosa_pseudoharengus_ott519457')
#             Clade(branch_length=1, name='mrcaott274ott392')
#                 Clade(branch_length=1, name='mrcaott274ott595')
#                     Clade(branch_length=1, name='mrcaott3887ott9371')
#                         Clade(branch_length=1, name='mrcaott31485ott79094')
#                             Clade(branch_length=1, name='mrcaott45127ott730762')
#                                 Clade(branch_length=1, name='Oncorhynchus_mykiss_-species_in_domain_Eukaryota-_ott165368')
#                                 Clade(branch_length=1, name='mrcaott730762ott739917')
#                                     Clade(branch_length=1, name='Oncorhynchus_tshawytscha_ott730762')
#                                     Clade(branch_length=1, name='Oncorhynchus_kisutch_ott739917')
#                             Clade(branch_length=1, name='Salmo_trutta_ott688332')
#                         Clade(branch_length=1, name='Esox_ott216166')
#                             Clade(branch_length=1, name='mrcaott9371ott366216')
#                                 Clade(branch_length=1, name='Esox_masquinongy_ott366216')
#                                 Clade(branch_length=1, name='Esox_lucius_ott739941')
#                             Clade(branch_length=1, name='Esox_niger_ott496121')
#                     Clade(branch_length=1, name='Osmerus_ott36124')
#                 Clade(branch_length=1, name='mrcaott392ott7815')
#                     Clade(branch_length=1, name='mrcaott392ott3549')
#                         Clade(branch_length=1, name='Cyprinodontoidei_ott312448')
#                             Clade(branch_length=1, name='mrcaott32586ott154103')
#                                 Clade(branch_length=1, name='mrcaott32586ott338515')
#                                     Clade(branch_length=1, name='Gambusia_alvarezi_ott3641783')
#                                     Clade(branch_length=1, name='Priapella_bonita_ott3641775')
#                                 Clade(branch_length=1, name='Brachyrhaphis_parismina_ott779448')
#                             Clade(branch_length=1, name='Fundulus_catenatus_ott519465')
#                         Clade(branch_length=1, name='mrcaott3549ott7508')
#                             Clade(branch_length=1, name='Morone_americana_ott769292')
#                             Clade(branch_length=1, name='mrcaott7508ott17627')
#                                 Clade(branch_length=1, name='mrcaott7508ott12409')
#                                     Clade(branch_length=1, name='mrcaott77068ott520261')
#                                         Clade(branch_length=1, name='mrcaott371626ott371627')
#                                             Clade(branch_length=1, name='mrcaott371626ott522507')
#                                                 Clade(branch_length=1, name='mrcaott371626ott520264')
#                                                     Clade(branch_length=1, name='Cottus_rhotheus_ott520264')
#                                                     Clade(branch_length=1, name='Cottus_bairdii_ott466855')
#                                                 Clade(branch_length=1, name='Cottus_cognatus_ott993337')
#                                             Clade(branch_length=1, name='Cottus_carolinae_ott466859')
#                                         Clade(branch_length=1, name='Cottus_perplexus_ott520261')
#                                     Clade(branch_length=1, name='Perca_flavescens_ott186474')
#                                 Clade(branch_length=1, name='mrcaott235372ott280003')
#                                     Clade(branch_length=1, name='mrcaott271244ott476359')
#                                         Clade(branch_length=1, name='Lepomis_ott836782')
#                                             Clade(branch_length=1, name='Lepomis_peltastes_ott4948997')
#                                             Clade(branch_length=1, name='mrcaott271244ott836783')
#                                                 Clade(branch_length=1, name='mrcaott271244ott271249')
#                                                     Clade(branch_length=1, name='mrcaott271244ott670266')
#                                                         Clade(branch_length=1, name='Lepomis_gibbosus_ott670266')
#                                                         Clade(branch_length=1, name='mrcaott271244ott271257')
#                                                             Clade(branch_length=1, name='Lepomis_microlophus_ott271244')
#                                                             Clade(branch_length=1, name='mrcaott271257ott274631')
#                                                                 Clade(branch_length=1, name='Lepomis_punctatus_ott271257')
#                                                                 Clade(branch_length=1, name='Lepomis_miniatus_ott274631')
#                                                     Clade(branch_length=1, name='mrcaott271249ott1002718')
#                                                         Clade(branch_length=1, name='Lepomis_auritus_ott1002718')
#                                                         Clade(branch_length=1, name='mrcaott271249ott943380')
#                                                             Clade(branch_length=1, name='Lepomis_megalotis_ott271249')
#                                                             Clade(branch_length=1, name='Lepomis_marginatus_ott943380')
#                                                 Clade(branch_length=1, name='mrcaott836783ott892772')
#                                                     Clade(branch_length=1, name='Lepomis_macrochirus_ott836783')
#                                                     Clade(branch_length=1, name='Lepomis_humilis_ott892772')
#                                             Clade(branch_length=1, name='mrcaott271254ott476361')
#                                                 Clade(branch_length=1, name='Lepomis_symmetricus_ott271254')
#                                                 Clade(branch_length=1, name='Lepomis_cyanellus_ott476361')
#                                         Clade(branch_length=1, name='Chaenobryttus_gulosus_ott476359')
#                                     Clade(branch_length=1, name='Enneacanthus_gloriosus_ott476364')
#                     Clade(branch_length=1, name='Neogobius_melanostomus_ott475633')
#         Clade(branch_length=1, name='Lepisosteus_ott904121')
#             Clade(branch_length=1, name='Lepisosteus_platostomus_ott731608')
#             Clade(branch_length=1, name='mrcaott519445ott804455')
#                 Clade(branch_length=1, name='Lepisosteus_osseus_ott519445')
#                 Clade(branch_length=1, name='Lepisosteus_oculatus_ott1028028')

# %%
species1 = "Lepisosteus_osseus_ott519445"
species2 = "Lepisosteus_oculatus_ott1028028"
print('(', species1, ',', species2, ') is ', tree.is_monophyletic([species1, species2]))
print("distance between", species1, " and ", species2, " is " , tree.distance(species1,species2))
# Out:
# ( Lepisosteus_osseus_ott519445 , Lepisosteus_oculatus_ott1028028 ) is  False
# distance between Lepisosteus_osseus_ott519445  and  Lepisosteus_oculatus_ott1028028  is  2

# %%
# tree_file = "/raid/elhamod/Fish/Curated4/Medium/cleaned_metadata.tre"
tree_file = "/raid/elhamod/Fish/Taxa/bgnn-tree-2021-01-29.tre"

# Read and print the tree
t = Tree(tree_file, format=8)

def getGenus(species):
    return species.split('_')[0]

for leaf in t:
    leaf.add_features(genus=getGenus(leaf.name))
    
# render
# print(t)
t.render('%%inline')

# %%
#Timetree package
print(t.get_ascii(attributes=["name", "genus"], show_internal=False))
# Out:
#                      /-Notropis_greenei_ott103051, Notropis
#                     |
#                     |--Notropis_nazas_ott338646, Notropis
#                     |
#                     |--Notropis_cummingsae_ott608193, Notropis
#                     |
#                     |   /-Notropis_hudsonius_ott135051, Notropis
#                     |  |
#                     |  |--Hybopsis_dorsalis_ott419160, Hybopsis
#                     |  |
#                     |  |            /-Lythrurus_umbratilis_ott260114, Lythrurus
#                     |  |         /-|
#                     |  |        |   \-Lythrurus_ardens_ott834748, Lythrurus
#                     |  |        |
#                     |  |      /-|         /-Luxilus_chrysocephalus_ott96048, Luxilus
#                     |  |     |  |      /-|
#                     |  |     |  |   /-|   \-Luxilus_cornutus_ott96051, Luxilus
#                     |  |     |  |  |  |
#                     |  |     |   \-|   \-Luxilus_zonatus_ott538618, Luxilus
#                     |  |     |     |
#                     |  |     |      \-Notropis_heterolepis_ott832483, Notropis
#                     |  |     |
#                     |  |     |         /-Cyprinella_lutrensis_ott351753, Cyprinella
#                     |  |     |      /-|
#                     |  |     |     |  |   /-Cyprinella_venusta_ott351750, Cyprinella
#                     |  |     |     |   \-|
#                     |  |     |     |     |   /-Cyprinella_spiloptera_ott373838, Cyprinella
#                     |  |   /-|   /-|      \-|
#                     |  |  |  |  |  |         \-Cyprinella_whipplei_ott597397, Cyprinella
#                     |  |  |  |  |  |
#                     |  |  |  |  |  |   /-Cyprinella_camura_ott570799, Cyprinella
#                     |  |  |  |  |   \-|
#                     |  |  |  |  |      \-Cyprinella_galactura_ott570805, Cyprinella
#                     |  |  |  |  |
#                     |  |  |  |  |               /-Notropis_rubricroceus_ott53715, Notropis
#                     |  |  |  |  |            /-|
#                     |  |  |  |  |           |   \-Notropis_lutipinnis_ott703205, Notropis
#                     |  |  |  |  |         /-|
#                     |  |  |  |  |        |  |   /-Notropis_edwardraneyi_ott443771, Notropis
#                     |  |  |  |  |        |   \-|
#                     |  |  |  |  |      /-|      \-Notropis_blennius_ott419165, Notropis
#                     |  |  |   \-|     |  |
#                     |  |  |     |     |  |   /-Notropis_chalybaeus_ott103071, Notropis
#                     |  |  |     |     |   \-|
#                     |  |  |     |     |     |   /-Notropis_texanus_ott550208, Notropis
#                     |  |  |     |     |      \-|
#                     |  |  |     |     |         \-Notropis_xaenocephalus_ott914937, Notropis
#                     |  |  |     |   /-|
#                     |  |  |     |  |  |--Ericymba_buccata_ott269524, Ericymba
#                     |  |  |     |  |  |
#                     |  |  |     |  |  |      /-Notropis_anogenus_ott258125, Notropis
#                   /-|  |  |     |  |  |   /-|
#                  |  |--|  |     |  |  |  |  |   /-Notropis_longirostris_ott280272, Notropis
#                  |  |  |  |     |  |  |  |   \-|
#                  |  |  |  |     |  |   \-|      \-Notropis_nubilus_ott550199, Notropis
#                  |  |  |  |      \-|     |
#                  |  |  |  |        |     |   /-Notropis_heterodon_ott258132, Notropis
#                  |  |  |  |        |      \-|
#                  |  |  |  |        |        |   /-Notropis_boops_ott443777, Notropis
#                  |  |  |  |        |         \-|
#                  |  |  |  |        |            \-Notropis_chihuahua_ott522918, Notropis
#                  |  |  |--|        |
#                  |  |  |  |        |   /-Notropis_procne_ott351732, Notropis
#                  |  |  |  |         \-|
#                  |  |  |  |           |   /-Notropis_topeka_ott351738, Notropis
#                  |  |  |  |            \-|
#                  |  |  |  |               \-Notropis_stramineus_ott351741, Notropis
#                  |  |  |  |
#                  |  |  |  |         /-Notropis_leuciodus_ott338652, Notropis
#                  |  |  |  |        |
#                  |  |  |  |      /-|   /-Notropis_volucellus_ott351735, Notropis
#                  |  |  |  |     |  |  |
#                  |  |  |  |     |   \-|      /-Notropis_spectrunculus_ott53720, Notropis
#                  |  |  |  |     |     |   /-|
#                  |  |  |  |     |      \-|   \-Notropis_buchanani_ott555686, Notropis
#                  |  |  |  |   /-|        |
#                  |  |  |  |  |  |         \-Notropis_wickliffi_ott563834, Notropis
#                  |  |  |  |  |  |
#                /-|  |  |  |  |  |   /-Notropis_ariommus_ott443780, Notropis
#               |  |  |  |  |  |  |  |
#               |  |  |  |  |  |  |  |         /-Notropis_micropteryx_ott403724, Notropis
#               |  |  |  |  |  |   \-|      /-|
#               |  |  |  |  |  |     |     |  |   /-Notropis_percobromus_ott403731, Notropis
#               |  |  |  |  |--|     |   /-|   \-|
#               |  |  |  |  |  |     |  |  |      \-Notropis_rubellus_ott565581, Notropis
#               |  |  |  |  |  |      \-|  |
#               |  |  |  |  |  |        |   \-Notropis_stilbius_ott550184, Notropis
#               |  |  |  |  |  |        |
#               |  |  |  |  |  |         \-Notropis_atherinoides_ott636312, Notropis
#               |  |  |  |  |  |
#               |  |  |  |  |  |   /-Notropis_telescopus_ott550190, Notropis
#               |  |  |  |  |   \-|
#               |  |  |  |  |      \-Notropis_photogenis_ott550202, Notropis
#               |  |  |  |  |
#             /-|  |  |  |  |   /-Notropis_bifrenatus_ott439044, Notropis
#            |  |  |  |  |   \-|
#            |  |  |  |  |      \-Luxilus_coccogenis_ott538612, Luxilus
#            |  |  |  |  |
#            |  |  |  |  |   /-Hybopsis_amblops_ott269514, Hybopsis
#            |  |  |  |   \-|
#            |  |  |  |      \-Opsopoeodus_emiliae_ott260128, Opsopoeodus
#            |  |  |  |
#            |  |  |   \-Phenacobius_uranops_ott610364, Phenacobius
#            |  |  |
#            |  |  |   /-Chrosomus_neogaeus_ott319954, Chrosomus
#          /-|  |   \-|
#         |  |  |     |   /-Chrosomus_eos_ott63845, Chrosomus
#         |  |  |      \-|
#         |  |  |         \-Chrosomus_erythrogaster_ott319949, Chrosomus
#         |  |  |
#         |  |  |   /-Cyprinus_carpio_ott429083, Cyprinus
#         |  |   \-|
#         |  |      \-Carassius_auratus_ott1005907, Carassius
#         |  |
#         |  |   /-Noturus_exilis_ott678206, Noturus
#         |  |  |
#       /-|   \-|      /-Noturus_insignis_ott621604, Noturus
#      |  |     |   /-|
#      |  |     |  |   \-Noturus_leptacanthus_ott621583, Noturus
#      |  |      \-|
#      |  |        |      /-Noturus_eleutherus_ott411926, Noturus
#      |  |        |   /-|
#      |  |         \-|   \-Noturus_albater_ott676110, Noturus
#      |  |           |
#      |  |            \-Noturus_hildebrandi_ott652781, Noturus
#      |  |
#      |  |   /-Alosa_chrysochloris_ott482298, Alosa
#      |   \-|
#      |      \-Alosa_pseudoharengus_ott519457, Alosa
#      |
#      |               /-Oncorhynchus_mykiss_-species_in_domain_Eukaryota-_ott165368, Oncorhynchus
#      |            /-|
#      |           |  |   /-Oncorhynchus_tshawytscha_ott730762, Oncorhynchus
#      |         /-|   \-|
#      |        |  |      \-Oncorhynchus_kisutch_ott739917, Oncorhynchus
#      |        |  |
#      |      /-|   \-Salmo_trutta_ott688332, Salmo
#    /-|     |  |
#   |  |     |  |      /-Esox_masquinongy_ott366216, Esox
#   |  |     |  |   /-|
#   |  |   /-|   \-|   \-Esox_lucius_ott739941, Esox
#   |  |  |  |     |
#   |  |  |  |      \-Esox_niger_ott496121, Esox
#   |  |  |  |
#   |  |  |   \-Osmerus_ott36124, Osmerus
#   |  |  |
#   |  |  |               /-Gambusia_alvarezi_ott3641783, Gambusia
#   |  |  |            /-|
#   |  |  |         /-|   \-Priapella_bonita_ott3641775, Priapella
#   |  |  |        |  |
#   |  |  |      /-|   \-Brachyrhaphis_parismina_ott779448, Brachyrhaphis
#   |  |  |     |  |
#   |  |  |     |   \-Fundulus_catenatus_ott519465, Fundulus
#   |  |  |     |
#   |  |  |     |   /-Morone_americana_ott769292, Morone
#   |  |  |     |  |
#   |  |  |     |  |                  /-Cottus_rhotheus_ott520264, Cottus
#   |  |  |   /-|  |               /-|
#   |   \-|  |  |  |            /-|   \-Cottus_bairdii_ott466855, Cottus
#   |     |  |  |  |           |  |
#   |     |  |  |  |         /-|   \-Cottus_cognatus_ott993337, Cottus
#   |     |  |  |  |        |  |
#   |     |  |  |  |      /-|   \-Cottus_carolinae_ott466859, Cottus
#   |     |  |  |  |     |  |
#   |     |  |  |  |   /-|   \-Cottus_perplexus_ott520261, Cottus
#   |     |  |   \-|  |  |
#   |     |  |     |  |   \-Perca_flavescens_ott186474, Perca
#   |     |  |     |  |
# --|     |  |     |  |         /-Lepomis_peltastes_ott4948997, Lepomis
#   |     |  |     |  |        |
#   |     |  |     |  |        |         /-Lepomis_gibbosus_ott670266, Lepomis
#   |     |  |     |  |        |      /-|
#   |     |  |     |  |        |     |  |   /-Lepomis_microlophus_ott271244, Lepomis
#   |     |  |     |  |        |     |   \-|
#   |     |  |     |  |        |     |     |   /-Lepomis_punctatus_ott271257, Lepomis
#   |     |  |     |  |        |   /-|      \-|
#   |      \-|      \-|        |  |  |         \-Lepomis_miniatus_ott274631, Lepomis
#   |        |        |        |  |  |
#   |        |        |      /-|  |  |   /-Lepomis_auritus_ott1002718, Lepomis
#   |        |        |     |  |  |   \-|
#   |        |        |     |  |--|     |   /-Lepomis_megalotis_ott271249, Lepomis
#   |        |        |     |  |  |      \-|
#   |        |        |     |  |  |         \-Lepomis_marginatus_ott943380, Lepomis
#   |        |        |     |  |  |
#   |        |        |     |  |  |   /-Lepomis_macrochirus_ott836783, Lepomis
#   |        |        |   /-|  |   \-|
#   |        |        |  |  |  |      \-Lepomis_humilis_ott892772, Lepomis
#   |        |        |  |  |  |
#   |        |        |  |  |  |   /-Lepomis_symmetricus_ott271254, Lepomis
#   |        |         \-|  |   \-|
#   |        |           |  |      \-Lepomis_cyanellus_ott476361, Lepomis
#   |        |           |  |
#   |        |           |   \-Chaenobryttus_gulosus_ott476359, Chaenobryttus
#   |        |           |
#   |        |            \-Enneacanthus_gloriosus_ott476364, Enneacanthus
#   |        |
#   |         \-Neogobius_melanostomus_ott475633, Neogobius
#   |
#   |   /-Lepisosteus_platostomus_ott731608, Lepisosteus
#    \-|
#      |   /-Lepisosteus_osseus_ott519445, Lepisosteus
#       \-|
#          \-Lepisosteus_oculatus_ott1028028, Lepisosteus

# %% [markdown]
# Check whether some species are monophylic or not

# %%
species1 = "Lepisosteus_osseus_ott519445"
species2 = "Lepisosteus_oculatus_ott1028028"
print('(', species1, ',', species2, ') is ', t.check_monophyly(values=[species1, species2], target_attr="name")[1])
print('(', species1, ',',species2, ') distance is ', t.get_distance(species1,species2))

species1 = "Lepomis_gibbosus_ott670266"
species2 = "Lepomis_microlophus_ott271244"
print('(', species1, ',',species2, ') is ', t.check_monophyly(values=[species1, species2], target_attr="name")[1])
print('(', species1, ',',species2, ') distance is ', t.get_distance(species1,species2))

species1 = "Neogobius_melanostomus_ott475633"
species2 = "Lepisosteus_oculatus_ott1028028"
print('(', species1, ',',species2, ') is ', t.check_monophyly(values=[species1, species2], target_attr="name")[1])
print('(', species1, ',',species2, ') distance is ', t.get_distance(species1,species2))
# Out:
# ( Lepisosteus_osseus_ott519445 , Lepisosteus_oculatus_ott1028028 ) is  monophyletic
# ( Lepisosteus_osseus_ott519445 , Lepisosteus_oculatus_ott1028028 ) distance is  2.0
# ( Lepomis_gibbosus_ott670266 , Lepomis_microlophus_ott271244 ) is  paraphyletic
# ( Lepomis_gibbosus_ott670266 , Lepomis_microlophus_ott271244 ) distance is  3.0
# ( Neogobius_melanostomus_ott475633 , Lepisosteus_oculatus_ott1028028 ) is  polyphyletic
# ( Neogobius_melanostomus_ott475633 , Lepisosteus_oculatus_ott1028028 ) distance is  7.0

# %% [markdown]
# Given a metadata spreadsheet, get the tree of that spreadsheet

# %%
# Look at research in metric learning using deep learning
#Adding triplet losses (with an anchor)

from opentree import OT
import pandas as pd

import pprint
pp = pprint.PrettyPrinter(indent=4)

from ete3 import Tree
# set flag for rendering
import os
os.environ['QT_QPA_PLATFORM']='offscreen'

# prefix_path = "/raid/elhamod/Fish/Curated4/Medium"
prefix_path = "/raid/elhamod/Fish/Curated4/Easy_50"
metadataFile = "cleaned_metadata.csv"
treefile = "cleaned_metadata.tre"

metadataFile = os.path.join(prefix_path, metadataFile)
treefile = os.path.join(prefix_path, treefile)

# Get the taxonomy
df = pd.read_csv(metadataFile, sep="\t") # , usecols=['scientificName']
df_nodupes = df['scientificName'].drop_duplicates() # Will probably need more processing to deal with small letter...etc
node_ids = df_nodupes.tolist()
print('Included taxonomy: ', node_ids, len(node_ids))

# df = pd.read_csv(metadataFile, sep="\t")

# get the response tree
resp = OT.tnrs_match(node_ids, do_approximate_matching=True)
# pp.pprint(resp.response_dict)
matches = resp.response_dict['results']
unmatched_names = resp.response_dict['unmatched_names']

# Get the corresponding ott_ids
df2 = pd.DataFrame(columns=['in csv', 'in response', 'Same?'])
ott_ids = set()
ott_id_dict={}
assert len(unmatched_names)==0 # everything is matched!
for match_array in matches:
    match_array_matches = match_array['matches']
    assert len(match_array_matches)==1, match_array['name'] + " has too many matches" + str(list(map(lambda x: x['matched_name'], match_array_matches)))  # we have one unambiguous match!
    first_match = match_array_matches[0]
    ott_id = first_match['taxon']['ott_id']
    ott_ids.add(ott_id)
    #some original and matched names are not exactly the same. Not a bug
    df2 = df2.append({'in csv':match_array['name'], 'in response': first_match['matched_name'], 'Same?': match_array['name'] == first_match['matched_name']}, ignore_index=True)
    print(match_array['name'], '\t -> \t', first_match['matched_name']) 
    ott_id_dict[match_array['name']] = ott_id
ott_ids = list(ott_ids)
print(df2[df2['Same?']== False])
# print(ott_ids, len(ott_ids))
pp.pprint(ott_id_dict)

# add ott_id to metadata csv file
df['ott_id'] = df.apply(lambda row: ott_id_dict[row['scientificName']], axis=1)
# print(df)

# save and print the tree

#Get the synthetic tree from OpenTree
output = OT.synth_induced_tree(ott_ids=ott_ids, ignore_unknown_ids=False, label_format='id') # name_and_id ott_ids=list(ott_ids),
print(output.tree)
output.tree.write(path = treefile, schema = "newick")
# output.tree.print_plot(width=100)
t = Tree(treefile, format=8)
D = t.search_nodes(name="mrcaott47023ott496121")[0]
D.name = "ott496115"
t.write(format=8, outfile=treefile)
t.render('%%inline')
# Out:
# Included taxonomy:  ['Gambusia affinis', 'Notropis stramineus', 'Lepomis cyanellus', 'Noturus gyrinus', 'Notropis atherinoides', 'Esox americanus', 'Lepomis macrochirus', 'Phenacobius mirabilis', 'Notropis buchanani', 'Lepomis humilis', 'Cyprinus carpio', 'Notropis boops', 'Morone chrysops', 'Lepomis gulosus', 'Notropis buccatus', 'Lepomis megalotis', 'Lepomis auritus', 'Notropis blennius', 'Notropis hudsonius', 'Noturus exilis', 'Notropis nubilus', 'Notropis dorsalis', 'Noturus flavus', 'Notropis volucellus', 'Lepomis microlophus', 'Notropis percobromus', 'Carassius auratus', 'Notropis wickliffi', 'Notropis telescopus', 'Morone mississippiensis', 'Lepisosteus platostomus', 'Noturus nocturnus', 'Lepomis gibbosus', 'Noturus miurus', 'Lepisosteus osseus', 'Notropis leuciodus', 'Notropis texanus', 'Alosa chrysochloris'] 38
# Gambusia affinis 	 -> 	 Gambusia affinis
# Notropis stramineus 	 -> 	 Notropis stramineus
# Lepomis cyanellus 	 -> 	 Lepomis cyanellus
# Noturus gyrinus 	 -> 	 Noturus gyrinus
# Notropis atherinoides 	 -> 	 Notropis atherinoides
# Esox americanus 	 -> 	 Esox americanus
# Lepomis macrochirus 	 -> 	 Lepomis macrochirus
# Phenacobius mirabilis 	 -> 	 Phenacobius mirabilis
# Notropis buchanani 	 -> 	 Notropis buchanani
# Lepomis humilis 	 -> 	 Lepomis humilis
# Cyprinus carpio 	 -> 	 Cyprinus carpio
# Notropis boops 	 -> 	 Notropis boops
# Morone chrysops 	 -> 	 Morone chrysops
# Lepomis gulosus 	 -> 	 Lepomis gulosus
# Notropis buccatus 	 -> 	 Notropis buccatus
# Lepomis megalotis 	 -> 	 Lepomis megalotis
# Lepomis auritus 	 -> 	 Lepomis auritus
# Notropis blennius 	 -> 	 Notropis blennius
# Notropis hudsonius 	 -> 	 Notropis hudsonius
# Noturus exilis 	 -> 	 Noturus exilis
# Notropis nubilus 	 -> 	 Notropis nubilus
# Notropis dorsalis 	 -> 	 Notropis dorsalis
# Noturus flavus 	 -> 	 Noturus flavus
# Notropis volucellus 	 -> 	 Notropis volucellus
# Lepomis microlophus 	 -> 	 Lepomis microlophus
# Notropis percobromus 	 -> 	 Notropis percobromus
# Carassius auratus 	 -> 	 Carassius auratus
# Notropis wickliffi 	 -> 	 Notropis wickliffi
# Notropis telescopus 	 -> 	 Notropis telescopus
# Morone mississippiensis 	 -> 	 Morone mississippiensis
# Lepisosteus platostomus 	 -> 	 Lepisosteus platostomus
# Noturus nocturnus 	 -> 	 Noturus nocturnus
# Lepomis gibbosus 	 -> 	 Lepomis gibbosus
# Noturus miurus 	 -> 	 Noturus miurus
# Lepisosteus osseus 	 -> 	 Lepisosteus osseus
# Notropis leuciodus 	 -> 	 Notropis leuciodus
# Notropis texanus 	 -> 	 Notropis texanus
# Alosa chrysochloris 	 -> 	 Alosa chrysochloris
# Empty DataFrame
# Columns: [in csv, in response, Same?]
# Index: []
# {   'Alosa chrysochloris': 482298,
#     'Carassius auratus': 1005907,
#     'Cyprinus carpio': 429083,
#     'Esox americanus': 496115,
#     'Gambusia affinis': 617445,
#     'Lepisosteus osseus': 519445,
#     'Lepisosteus platostomus': 731608,
#     'Lepomis auritus': 1002718,
#     'Lepomis cyanellus': 476361,
#     'Lepomis gibbosus': 670266,
#     'Lepomis gulosus': 476359,
#     'Lepomis humilis': 892772,
#     'Lepomis macrochirus': 836783,
#     'Lepomis megalotis': 271249,
#     'Lepomis microlophus': 271244,
#     'Morone chrysops': 246133,
#     'Morone mississippiensis': 769290,
#     'Notropis atherinoides': 636312,
#     'Notropis blennius': 419165,
#     'Notropis boops': 443777,
#     'Notropis buccatus': 269524,
#     'Notropis buchanani': 555686,
#     'Notropis dorsalis': 419160,
#     'Notropis hudsonius': 135051,
#     'Notropis leuciodus': 338652,
#     'Notropis nubilus': 550199,
#     'Notropis percobromus': 403731,
#     'Notropis stramineus': 351741,
#     'Notropis telescopus': 550190,
#     'Notropis texanus': 550208,
#     'Notropis volucellus': 351735,
#     'Notropis wickliffi': 563834,
#     'Noturus exilis': 678206,
#     'Noturus flavus': 101864,
#     'Noturus gyrinus': 652777,
#     'Noturus miurus': 282530,
#     'Noturus nocturnus': 621586,
#     'Phenacobius mirabilis': 945111}
# ((((((((((((((((((((((((((((((((((((ott419165)mrcaott419165ott570943)mrcaott419165ott443771)mrcaott419165ott443774)mrcaott53715ott419165,(((ott550208)mrcaott550208ott914937)mrcaott103071ott550208)mrcaott53730ott103071)mrcaott53715ott53730,(ott269524)ott229846,((((ott550199)mrcaott550199ott698753)mrcaott280272ott550199)mrcaott258125ott280272,((ott443777)mrcaott443777ott522918)mrcaott258132ott443777)mrcaott258125ott258132)mrcaott53715ott103057,((((ott351741)mrcaott351738ott351741)mrcaott351732ott351738)mrcaott280276ott351732)mrcaott222462ott280276)mrcaott53715ott222462)mrcaott50039ott53715)mrcaott231ott50039,((((((((ott555686)mrcaott53720ott555686,(ott563834)mrcaott443786ott563834)mrcaott53720ott443786)mrcaott53720ott677055,ott351735)mrcaott53720ott351735)mrcaott53720ott103081,ott338652)mrcaott53720ott338652,(((((ott403731)mrcaott403731ott565581)mrcaott403724ott403731)mrcaott403724ott443768,((ott636312)mrcaott550196ott636312)mrcaott443765ott550196)mrcaott403724ott443765)mrcaott403724ott443780)mrcaott53720ott403724,((ott550190)mrcaott550190ott550202)mrcaott550187ott550190)mrcaott53720ott550187)mrcaott231ott53720,ott135051,ott419160)mrcaott231ott101080,((((ott945111)ott636315)mrcaott108437ott610364)mrcaott108437ott608188)mrcaott108437ott361216)mrcaott231ott103051)mrcaott231ott636305)mrcaott231ott222446)mrcaott231ott30152)mrcaott231ott411057)mrcaott231ott290054)mrcaott231ott1031056)mrcaott231ott14745)mrcaott231ott3121)mrcaott231ott19423)mrcaott231ott14765)mrcaott231ott24463)mrcaott231ott72785,((((((((((ott429083)mrcaott255956ott310585)ott429094)mrcaott169910ott3627538,(((((ott1005907)mrcaott185860ott363937)mrcaott185860ott1010092)mrcaott185860ott1001674)mrcaott185860ott1090373)mrcaott185860ott948890)mrcaott169910ott185860)mrcaott78222ott169910)mrcaott78222ott89282)mrcaott45793ott78222)mrcaott2200ott45793)mrcaott2200ott22243)mrcaott2200ott14758)mrcaott231ott2200)ott239839)ott1005931)ott285817,((((((((((((((((((ott101864)mrcaott101864ott139659)mrcaott101864ott652763)mrcaott101864ott621604,((((ott282530)mrcaott282525ott282530)mrcaott282525ott676110)mrcaott282525ott411931)mrcaott130869ott282525)mrcaott101864ott130869,((ott652777)mrcaott621580ott652777,ott621586)mrcaott621580ott621586)mrcaott101864ott621580,ott678206)ott357170)mrcaott101864ott1014995)mrcaott101864ott206286)ott701513)mrcaott101864ott261881)mrcaott13190ott101864)mrcaott801ott13190)mrcaott801ott23762)ott5548749)mrcaott801ott536094)ott701516)mrcaott801ott1070)ott285825)ott285818)ott803544)mrcaott231ott170507,((((((((((((ott482298)mrcaott482298ott491656)ott272032)mrcaott21578ott215046)mrcaott21578ott25754)mrcaott1195ott21578)mrcaott1195ott100785)mrcaott1195ott610194)mrcaott1195ott9666)mrcaott1195ott12224)ott5541314)ott400458)ott705411)ott761450,(((((((((((mrcaott47023ott496121)ott216166)ott216164)mrcaott9371ott586186)mrcaott9371ott357530)ott216172)mrcaott3887ott9371)mrcaott274ott3887)ott1024043)mrcaott274ott595,((((((((((((((((((((((((((((((((((((((((ott617445)mrcaott553631ott617445)mrcaott234719ott553631)mrcaott223699ott234719)mrcaott223699ott553623)mrcaott223699ott387853)mrcaott32586ott223699)mrcaott32586ott170247)mrcaott32586ott913297)mrcaott32586ott226293)mrcaott32586ott338515)mrcaott32586ott247003)mrcaott32586ott32908)mrcaott32586ott154103)mrcaott32586ott399707)mrcaott6454ott32586)mrcaott6454ott498235)ott399706)ott583631)mrcaott6454ott134560)mrcaott6454ott24425)mrcaott6454ott24429)ott312448)ott338836)mrcaott6454ott6991)ott976556)mrcaott6221ott6454)ott5553750)mrcaott392ott497)mrcaott392ott12213,((((((((ott246133,(ott769290)mrcaott769290ott769292)mrcaott246133ott769290)ott223661)ott1032209)mrcaott3549ott143050)mrcaott3549ott6406)mrcaott3549ott5050,(((((((((((((((((ott271244)mrcaott271244ott271257,ott670266)mrcaott271244ott670266,((ott271249)mrcaott271249ott943380,ott1002718)mrcaott271249ott1002718)mrcaott271244ott271249,(ott836783,ott892772)mrcaott836783ott892772)mrcaott271244ott836783,(ott476361)mrcaott271254ott476361)ott836782,(ott476359)ott1002717)mrcaott271244ott47635 ...

# %%
# from opentree import OT

# import pprint
# pp = pprint.PrettyPrinter(indent=4)

# from ete3 import Tree

# node_ids=["Homo sapiens", "Mus musculus", "Ameiurus catus"]
# resp = OT.tnrs_match(node_ids, do_approximate_matching=True)
# # pp.pprint(resp.response_dict)
# matches = resp.response_dict['results']
# ott_ids=set()
# for match_array in matches:
#     match_array_matches = match_array['matches']
#     assert len(match_array_matches)==1, match_array['name'] + " has too many matches" + str(list(map(lambda x: x['matched_name'], match_array_matches)))  # we have one unambiguous match!
#     first_match = match_array_matches[0]
#     ott_id = first_match['taxon']['ott_id']
#     ott_ids.add(ott_id)
# ott_ids = list(ott_ids)
# output12 = OT.synth_induced_tree(ott_ids=ott_ids, ignore_unknown_ids=False, label_format='name_and_id') # name_and_id ott_ids=list(ott_ids),
# print(output12.tree)
# treefile12="deleteme.tre"
# output12.tree.write(path = treefile12, schema = "newick")
# # output.tree.print_plot(width=100)
# t12 = Tree(treefile12, format=8)
# # D = t.search_nodes(name="mrcaott47023ott496121")[0]
# # D.name = "ott496115"
# t12.write(format=8, outfile=treefile12)
# t12.render('%%inline')

# %%
# pp.pprint(resp.response_dict)

# %%
# matched name -> ott -> save in csv
# load csv -> look at tree ->get distance

species1 = 'Notropis blennius'
species2 = 'Notropis texanus'

ott_id1 = 'ott' + str(ott_id_dict[species1])
ott_id2 = 'ott' + str(ott_id_dict[species2])

print('distance between', species1, 'and', species2, 'is', t.get_distance(ott_id1, ott_id2))
# Out:
# distance between Notropis blennius and Notropis texanus is 9.0

# %%
# pp.pprint(resp.response_dict)

# %%
t = Tree('/raid/elhamod/Fish/Curated4/Easy_50/cleaned_metadata.tre', format=1)
t.render('%%inline')

# %%
print(t)
# Out:
#                                                                                                 /- /- /- /- /-ott419165
#                                                                                              /-|
#                                                                                             |   \- /- /- /-ott550208
#                                                                                             |
#                                                                                           /-|-- /-ott269524
#                                                                                          |  |
#                                                                                          |  |   /- /- /- /-ott550199
#                                                                                  /- /- /-|   \-|
#                                                                                 |        |      \- /- /-ott443777
#                                                                                 |        |
#                                                                                 |         \- /- /- /- /-ott351741
#                                                                                 |
#                                                                                 |                     /- /-ott555686
#                                                                                 |               /- /-|
#                                                                               /-|         /- /-|      \- /-ott563834
#                                                                              |  |        |     |
#                                                                              |  |      /-|      \-ott351735
#                                                                              |  |     |  |
#                                                                              |  |   /-|   \-ott338652
#                                                                              |  |  |  |
#                                                                              |  |  |  |      /- /- /- /-ott403731
#                                                                            /-|   \-|   \- /-|
#                                                                           |  |     |         \- /- /-ott636312
#                                                                           |  |     |
#                                                                           |  |      \- /- /-ott550190
#                                     /- /- /- /- /- /- /- /- /- /- /- /- /-|  |
#                                    |                                      |  |--ott135051
#                                    |                                      |  |
#                                    |                                      |   \-ott419160
#                         /- /- /- /-|                                      |
#                        |           |                                       \- /- /- /- /-ott945111
#                        |           |
#                        |           |                     /- /- /- /-ott429083
#                        |            \- /- /- /- /- /- /-|
#                        |                                 \- /- /- /- /- /-ott1005907
#                /- /- /-|
#               |        |                                             /- /- /- /-ott101864
#               |        |                                          /-|
#               |        |                                         |   \- /- /- /- /-ott282530
#               |        |                                       /-|
#             /-|        |                                      |  |   /- /-ott652777
#            |  |         \- /- /- /- /- /- /- /- /- /- /- /- /-|   \-|
#            |  |                                               |      \-ott621586
#            |  |                                               |
#            |  |                                                \-ott678206
#    /- /- /-|  |
#   |        |   \- /- /- /- /- /- /- /- /- /- /- /- /-ott482298
#   |        |
#   |        |      /- /- /- /- /- /- /- /- /- /-ott496115
#   |        |     |
#   |        |     |                                 /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /- /-ott617445
#   |         \- /-|                                |
#   |              |                                |                        /-ott246133
#   |              |                                |      /- /- /- /- /- /-|
#   |              |                                |     |                  \- /-ott769290
#   |               \- /- /- /- /- /- /- /- /- /- /-|     |
#   |                                               |     |                                                /- /-ott271244
#   |                                               |     |                                             /-|
#   |                                               |     |                                            |   \-ott670266
# --|                                               |     |                                          /-|
#   |                                                \- /-|                                         |  |   /- /-ott271249
#   |                                                     |                                         |   \-|
#   |                                                     |                                       /-|      \-ott1002718
#   |                                                     |                                      |  |
#   |                                                     |                                      |  |   /-ott836783
#   |                                                     |                                    /-|   \-|
#   |                                                     |                                   |  |      \-ott892772
#   |                                                      \- /- /- /- /- /- /- /- /- /- /- /-|  |
#   |                                                                                         |   \- /-ott476361
#   |                                                                                         |
#   |                                                                                          \- /-ott476359
#   |
#   |            /- /-ott519445
#    \- /- /- /-|
#                \-ott731608

# %%
josef_tree_path="/home/elhamod/projects/HGNN/code/HGNN/HGNN/Josephscript/Output/datelife.phy"
ttt = Tree(josef_tree_path, format=1)
ttt.render('%%inline')
# For all nodes, replace name woth ottid
